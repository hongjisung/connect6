# %%
import pandas as pd
from pandas import Series, DataFrame
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("data2.csv")

# %%
col = df.columns
col = [i.strip() for i in col]
df.columns = col

# %%
x_data = df[col[:-1]]
y_data = df.pop("result")

# %%
y_data.replace({" WIN":1, " LOSE":0, "WIN":1, "LOSE":0}, inplace=True)

# %%
lr = LogisticRegression()
lr.fit(x_data,y_data)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# make the one hot encoded data to find the parameter
test = [[0  for j in range(0,len(col)-1)] for i in range(0,len(col)-1)]
for i in range(0,len(col)-1):
    test[i][i] = 1
dt = pd.DataFrame(test)

# %%
params = list(lr.decision_function(dt))

# %%
f = open('save.txt', 'w')
f.write('{')
for p in params:
    f.write(str(p))
    f.write(',')
f.write('}')
f.close()

# %%
lr.decision_function(df)
# Out:
# array([ 8.73255722e-01,  1.10348567e+00,  1.56331346e-01,  8.96375531e-01,
#         7.21231832e-01,  8.08503373e-01,  1.26643387e+00,  1.07180753e+00,
#         1.25483381e+00,  2.59783790e-01, -6.03006172e-01, -8.73302770e-01,
#        -1.10351901e+00, -1.56301089e-01, -8.96259054e-01, -7.21033442e-01,
#        -8.08389955e-01, -1.26637252e+00, -1.07168510e+00, -1.25482333e+00,
#        -2.59726818e-01,  6.03030452e-01, -3.55861072e-01,  8.21459142e-01,
#        -4.30731044e-01,  1.09905692e+00,  6.40315146e-01,  1.42721112e+00,
#         3.68914376e+00,  2.25470299e+00,  2.57275688e+00,  2.04049304e+00,
#         2.78200961e+00,  5.28224844e+00,  8.08887919e+00,  9.42061732e+00,
#         5.85732565e+00,  2.56434670e-01,  3.55838727e-01, -8.21538536e-01,
#         4.30766351e-01, -1.09902013e+00, -6.40356880e-01, -1.42710524e+00,
#        -3.68900319e+00, -2.25458249e+00, -2.57262638e+00, -2.04042782e+00,
# ...

# %%
idx=0;
for k in range(0,2):
    for i in range(6,20):
        for j in range(1,i+1):
            print(k,",",i,",",j,": ",params[idx])
            idx+=1
# Out:
# 0 , 6 , 1 :  -0.33068323514546266
# 0 , 6 , 2 :  -0.11094602230501843
# 0 , 6 , 3 :  -0.09584392427172787
# 0 , 6 , 4 :  1.5092576696611198e-05
# 0 , 6 , 5 :  1.5092576696611198e-05
# 0 , 6 , 6 :  1.5092576696611198e-05
# 0 , 7 , 1 :  0.14437303821300282
# 0 , 7 , 2 :  -1.358594780475064
# 0 , 7 , 3 :  -0.04793428749955219
# 0 , 7 , 4 :  1.5092576696611198e-05
# 0 , 7 , 5 :  1.5092576696611198e-05
# 0 , 7 , 6 :  1.5092576696611198e-05
# 0 , 7 , 7 :  1.5092576696611198e-05
# 0 , 8 , 1 :  -0.2948371095056486
# 0 , 8 , 2 :  -0.6182465207924168
# 0 , 8 , 3 :  0.009101170506526934
# 0 , 8 , 4 :  -0.02507969467636512
# 0 , 8 , 5 :  1.5092576696611198e-05
# 0 , 8 , 6 :  1.5092576696611198e-05
# 0 , 8 , 7 :  1.5092576696611198e-05
# 0 , 8 , 8 :  1.5092576696611198e-05
# 0 , 9 , 1 :  0.15688544199598284
# 0 , 9 , 2 :  0.002388545853139564
# 0 , 9 , 3 :  0.8143819208581707
# 0 , 9 , 4 :  0.2654064717622396
# 0 , 9 , 5 :  1.5092576696611198e-05
# 0 , 9 , 6 :  1.5092576696611198e-05
# ...
